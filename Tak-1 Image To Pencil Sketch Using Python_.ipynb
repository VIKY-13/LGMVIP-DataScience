# %% [markdown]
# <a href="https://colab.research.google.com/github/VIKY-13/LGMVIP-DataScience/blob/main/Tak-1%20Image%20To%20Pencil%20Sketch%20Using%20Python_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Task-1 Image To Pencil Sketch Using Python
# #NAME - VIGNESH V M

# %%
from google.colab.patches import cv2_imshow

# %%
import cv2

# %%
img = cv2.imread("M.jpg")

# %%
cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=RGB size=300x400 at 0x7FC9ACE85C10>

# %%
img_gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

# %%
cv2_imshow(img_gray)
# Out:
# <PIL.Image.Image image mode=L size=300x400 at 0x7FC9ACE96310>

# %%
img_invert = cv2.bitwise_not(img_gray)

# %%
cv2_imshow(img_invert)
# Out:
# <PIL.Image.Image image mode=L size=300x400 at 0x7FC9ACEA7C10>

# %%
img_smoothing = cv2.GaussianBlur(img, (21, 21), sigmaX=0, sigmaY=0)
img_smoothing_gray = cv2.GaussianBlur(img_gray, (21, 21), sigmaX=0, sigmaY=0)
img_smoothing_gray_invert = cv2.GaussianBlur(img_invert, (21, 21), sigmaX=0, sigmaY=0)
cv2_imshow(img_smoothing)
cv2_imshow(img_smoothing_gray)
cv2_imshow(img_smoothing_gray_invert)
# Out:
# <PIL.Image.Image image mode=RGB size=300x400 at 0x7FC9ADEFE2D0>
# <PIL.Image.Image image mode=L size=300x400 at 0x7FC9ACE85550>
# <PIL.Image.Image image mode=L size=300x400 at 0x7FC9ACE85E50>

# %%
inverted_blurred = 255 - img_smoothing_gray_invert
pencil_sketch = cv2.divide(img_gray, inverted_blurred, scale=256.0)
cv2_imshow(img)
cv2_imshow(pencil_sketch)
# Out:
# <PIL.Image.Image image mode=RGB size=300x400 at 0x7FC9ADEFE3D0>
# <PIL.Image.Image image mode=L size=300x400 at 0x7FC9ADEFE910>
